# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', -1)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="root",
  database="wapo"
)

# %%
mydb

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# (u'reports',)

# %%
#mycursor.execute("select articleType,count(id) from reports group by articleType")
query = "SELECT count(id),articleType FROM reports group by articleType LIMIT 0,1000"
query2 = "SELECT title from reports"

#mycursor.execute(query)

#for x in mycursor:
#  print(x)

# %%
query = "select * from reports where reports.id='7ef8ce1720bf2f6b2065a97506ee89b4'"
df = pd.read_sql(query, con=mydb) # 50000 takes 1.2 gb in python 72 mb for 1000
df[['title','content']]
# Out:
#                                                                             title  \
# 0  How major U.S. cities and transit systems are reacting to the Brussels attacks
#
# ...

# %%
query = "select * from reports where reports.id='e8b396d2774dff51cf163539e235176e'"
df = pd.read_sql(query, con=mydb)
df[['title','content']]

# %%
df.describe(include='all')
# Out:
#                                       id  \
# count   1
# unique  1
# top     52abe793674f6edec6d797d6994be72a
# freq    1
#
#                                                                                                         url  \
# count   1
# unique  1
# top     https://www.washingtonpost.com/news/sports/wp/2014/12/11/clarity-from-cubs-dodgers-at-mlbs-winter-m
# freq    1
#
#                                                                                   title  \
# count   1
# unique  1
# top     Clarity from Cubs, Dodgers at MLB’s Winter Meetings; Nationals remain a mystery
# freq    1
#
#                author           date               source articleType  \
# count   1              1              1                    1
# unique  1              1              1                    1
# top     Barry Svrluga  1418335415000  The Washington Post  Sports
# freq    1              1              1                    1
#
# ...

# %%
df.sort_values("count(id)", axis = 0, ascending = False, 
                 inplace = True, na_position ='first')

# %%
df
# Out:
#      count(id)             articleType
# 90       39676                   Local
# 154      28121                 The Fix
# 50       24816              Early Lead
# 125      20066           Post Politics
# 116      18795                 Opinion
# 117      17505                Opinions
# 183      17455                Wonkblog
# 88       13654   Letters to the Editor
# 100      13285             Morning Mix
# 146      12815                  Sports
# 187      12238              WorldViews
# 121      12009                Politics
# 148      11524                   Style
# 41       10636         D.C. Sports Bog
# 28        9500    Capital Weather Gang
# 9         9480            AllMetSports
# 15        9351  Arts and Entertainment
# 26        8872                Business
# 174       7614    Washington Nationals
# 59        7476                 Express
# 124       7354             Post Nation
# 68        7137         Going Out Guide
# 155       6974             The Insider
# ...

# %%
#export_csv = df.to_csv ('/home/i3/git/WapoDataMining/python-interface/articleTypeCount.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
df.articleType.values
# Out:
# array([u'Local', u'The Fix', u'Early Lead', u'Post Politics', u'Opinion',
#        u'Opinions', u'Wonkblog', u'Letters to the Editor', u'Morning Mix',
#        u'Sports', u'WorldViews', u'Politics', u'Style',
#        u'D.C. Sports Bog', u'Capital Weather Gang', u'AllMetSports',
#        u'Arts and Entertainment', u'Business', u'Washington Nationals',
#        u'Express', u'Post Nation', u'Going Out Guide', u'The Insider',
#        u'The Switch', u'Analysis', u'Right Turn', u'Gridlock',
#        u'PowerPost', u'Capital Business', u'The Plum Line',
#        u'Public Safety', u'Health & Science', u'Education',
#        u'PostEverything', u'Reliable Source', u'Monkey Cage',
#        u'National Security', u'Obituaries', u'Answer Sheet',
#        u"The Post's View", u'Washington Capitals', u'Food', u'World',
#        u'Maryland Politics', u'The Volokh Conspiracy', u'Erik Wemple',
#        u'Colleges', u'Fancy Stats', u'Books', u'Virginia Politics',
# ...
